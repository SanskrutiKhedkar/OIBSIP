# %% [markdown]
# #Oasis Infotech - DATA ANALYTICS INTERNSHIP
#
# #Name: Sanskruti Satish Khedkar
#
# # Task - 03
#
# #Customer Segmentation Analysis

# %%
import pandas as pd

# Load the dataset

df = pd.read_csv("ifood_df.csv")

# %%
df.head()
# Out:
#     Income  Kidhome  Teenhome  Recency  MntWines  MntFruits  MntMeatProducts  \
# 0  58138.0        0         0       58       635         88              546
# 1  46344.0        1         1       38        11          1                6
# 2  71613.0        0         0       26       426         49              127
# 3  26646.0        1         0       26        11          4               20
# 4  58293.0        1         0       94       173         43              118
#
#    MntFishProducts  MntSweetProducts  MntGoldProds  ...  marital_Together  \
# 0              172                88            88  ...                 0
# 1                2                 1             6  ...                 0
# 2              111                21            42  ...                 1
# 3               10                 3             5  ...                 1
# 4               46                27            15  ...                 0
#
# ...

# %%
df.tail()
# Out:
#        Income  Kidhome  Teenhome  Recency  MntWines  MntFruits  \
# 2200  61223.0        0         1       46       709         43
# 2201  64014.0        2         1       56       406          0
# 2202  56981.0        0         0       91       908         48
# 2203  69245.0        0         1        8       428         30
# 2204  52869.0        1         1       40        84          3
#
#       MntMeatProducts  MntFishProducts  MntSweetProducts  MntGoldProds  ...  \
# 2200              182               42               118           247  ...
# 2201               30                0                 0             8  ...
# 2202              217               32                12            24  ...
# 2203              214               80                30            61  ...
# 2204               61                2                 1            21  ...
#
#       marital_Together  marital_Widow  education_2n Cycle  education_Basic  \
# ...

# %%
missing_values = df.isnull().sum()
print(missing_values[missing_values > 0])
# Out:
# Series([], dtype: int64)

# %% [markdown]
# # Descriptive Statistics

# %%
descriptive_stats = df.describe()
print(descriptive_stats)
# Out:
#               Income      Kidhome     Teenhome      Recency     MntWines  \
# count    2205.000000  2205.000000  2205.000000  2205.000000  2205.000000
# mean    51622.094785     0.442177     0.506576    49.009070   306.164626
# std     20713.063826     0.537132     0.544380    28.932111   337.493839
# min      1730.000000     0.000000     0.000000     0.000000     0.000000
# 25%     35196.000000     0.000000     0.000000    24.000000    24.000000
# 50%     51287.000000     0.000000     0.000000    49.000000   178.000000
# 75%     68281.000000     1.000000     1.000000    74.000000   507.000000
# max    113734.000000     2.000000     2.000000    99.000000  1493.000000
#
#          MntFruits  MntMeatProducts  MntFishProducts  MntSweetProducts  \
# count  2205.000000      2205.000000      2205.000000       2205.000000
# mean     26.403175       165.312018        37.756463         27.128345
# std      39.784484       217.784507        54.824635         41.130468
# ...

# %%
df.describe()
# Out:
#               Income      Kidhome     Teenhome      Recency     MntWines  \
# count    2205.000000  2205.000000  2205.000000  2205.000000  2205.000000
# mean    51622.094785     0.442177     0.506576    49.009070   306.164626
# std     20713.063826     0.537132     0.544380    28.932111   337.493839
# min      1730.000000     0.000000     0.000000     0.000000     0.000000
# 25%     35196.000000     0.000000     0.000000    24.000000    24.000000
# 50%     51287.000000     0.000000     0.000000    49.000000   178.000000
# 75%     68281.000000     1.000000     1.000000    74.000000   507.000000
# max    113734.000000     2.000000     2.000000    99.000000  1493.000000
#
#          MntFruits  MntMeatProducts  MntFishProducts  MntSweetProducts  \
# count  2205.000000      2205.000000      2205.000000       2205.000000
# mean     26.403175       165.312018        37.756463         27.128345
# std      39.784484       217.784507        54.824635         41.130468
# ...

# %%
df.shape
# Out:
# (2205, 39)

# %%
df.columns
# Out:
# Index(['Income', 'Kidhome', 'Teenhome', 'Recency', 'MntWines', 'MntFruits',
#        'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts',
#        'MntGoldProds', 'NumDealsPurchases', 'NumWebPurchases',
#        'NumCatalogPurchases', 'NumStorePurchases', 'NumWebVisitsMonth',
#        'AcceptedCmp3', 'AcceptedCmp4', 'AcceptedCmp5', 'AcceptedCmp1',
#        'AcceptedCmp2', 'Complain', 'Z_CostContact', 'Z_Revenue', 'Response',
#        'Age', 'Customer_Days', 'marital_Divorced', 'marital_Married',
#        'marital_Single', 'marital_Together', 'marital_Widow',
#        'education_2n Cycle', 'education_Basic', 'education_Graduation',
#        'education_Master', 'education_PhD', 'MntTotal', 'MntRegularProds',
#        'AcceptedCmpOverall'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Income                  0
# Kidhome                 0
# Teenhome                0
# Recency                 0
# MntWines                0
# MntFruits               0
# MntMeatProducts         0
# MntFishProducts         0
# MntSweetProducts        0
# MntGoldProds            0
# NumDealsPurchases       0
# NumWebPurchases         0
# NumCatalogPurchases     0
# NumStorePurchases       0
# NumWebVisitsMonth       0
# AcceptedCmp3            0
# AcceptedCmp4            0
# AcceptedCmp5            0
# AcceptedCmp1            0
# AcceptedCmp2            0
# Complain                0
# Z_CostContact           0
# Z_Revenue               0
# Response                0
# Age                     0
# Customer_Days           0
# marital_Divorced        0
# marital_Married         0
# marital_Single          0
# marital_Together        0
# marital_Widow           0
# education_2n Cycle      0
# education_Basic         0
# education_Graduation    0
# education_Master        0
# ...

# %%
purchase_frequency = df['Recency'].mean()
print("Frequency of Purchases (days since last purchase):", purchase_frequency)
# Out:
# Frequency of Purchases (days since last purchase): 49.00907029478458

# %%
average_purchase_value = df['MntTotal'].mean()
print("Average Purchase Value:", average_purchase_value)
# Out:
# Average Purchase Value: 562.7646258503402

# %% [markdown]
# # DATA EXPLORATION

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.boxplot(df['Income'])
plt.title('Box Plot of Income')
plt.ylabel('Income')
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.boxplot(df['MntTotal'])
plt.title('Box Plot of Total Amount Spent')
plt.ylabel('Total Amount Spent')
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.hist(df['Income'], bins=30, edgecolor='k', alpha=0.7)
plt.title('Histogram of Income')
plt.xlabel('Income')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.hist(df['MntTotal'], bins=30, edgecolor='k', alpha=0.7)
plt.title('Histogram of Total Amount Spent')
plt.xlabel('Total Amount Spent')
plt.ylabel('Frequency')
plt.show()

# %%
import seaborn as sns


# Calculate the correlation matrix
correlation_matrix = df.corr()

# Display the correlation matrix
print(correlation_matrix)
# Out:
#                         Income   Kidhome  Teenhome   Recency  MntWines  \
# Income                1.000000 -0.531699  0.042483  0.006716  0.730495
# Kidhome              -0.531699  1.000000 -0.040207  0.011829 -0.499288
# Teenhome              0.042483 -0.040207  1.000000  0.013881  0.002783
# Recency               0.006716  0.011829  0.013881  1.000000  0.016470
# MntWines              0.730495 -0.499288  0.002783  0.016470  1.000000
# MntFruits             0.537920 -0.374388 -0.176925 -0.004909  0.384947
# MntMeatProducts       0.702500 -0.445665 -0.267177  0.026138  0.593119
# MntFishProducts       0.551758 -0.389895 -0.206371  0.001177  0.395967
# MntSweetProducts      0.555601 -0.379101 -0.164246  0.025535  0.388613
# MntGoldProds          0.417653 -0.356550 -0.019619  0.018558  0.390194
# NumDealsPurchases    -0.132427  0.226434  0.394341  0.000479  0.011858
# NumWebPurchases       0.503184 -0.375590  0.161229 -0.005104  0.552342
# ...

# %%
plt.figure(figsize=(20, 10))
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix Heatmap')
plt.show()

# %% [markdown]
# # Customer Segmentation

# %%
from sklearn.preprocessing import StandardScaler

features = df[['Income', 'Recency', 'MntTotal']]
scaler = StandardScaler()
scaled_features = scaler.fit_transform(features)

# %%
#K-means Clustering:
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=3, random_state=42)
clusters = kmeans.fit_predict(scaled_features)
df['Cluster'] = clusters
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %% [markdown]
# # Visualization

# %%
import matplotlib.pyplot as plt

plt.scatter(df['Income'], df['MntTotal'], c=df['Cluster'])
plt.xlabel('Income')
plt.ylabel('Total Amount Spent')
plt.title('Customer Segments')
plt.show()

# %%
# Boxplot Income By Cluster
plt.figure(figsize=(8, 6))
sns.boxplot(x='Cluster', y='Income', data=df, palette='viridis')
plt.title('Income by cluster')
plt.xlabel('Cluster')
plt.ylabel('Income')
# Out:
# <ipython-input-30-12571ca929e1>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Cluster', y='Income', data=df, palette='viridis')
# Text(0, 0.5, 'Income')

# %% [markdown]
# # Insights and Recommendations

# %%
segment_summary = df.groupby('Cluster').mean()
print(segment_summary)
# Out:
#                Income   Kidhome  Teenhome    Recency    MntWines  MntFruits  \
# Cluster
# 0        39457.476529  0.631579  0.544808  22.822191  114.830725   9.115220
# 1        73466.201018  0.075064  0.405852  49.662850  650.132316  57.427481
# 2        39586.143855  0.659218  0.579609  74.002793  116.428771   9.319832
#
#          MntMeatProducts  MntFishProducts  MntSweetProducts  MntGoldProds  \
# Cluster
# 0              48.325747        13.755334          9.167852     27.530583
# 1             379.161578        82.013995         58.891858     73.693384
# 2              45.417598        12.737430          9.893855     27.750000
#
#          ...  marital_Together  marital_Widow  education_2n Cycle  \
# Cluster  ...
# 0        ...          0.238976       0.034139            0.095306
# 1        ...          0.250636       0.048346            0.075064
# 2        ...          0.283520       0.019553            0.100559
#
# ...

# %% [markdown]
# **Recommendations**
#
# Target High-Value Customers:
# Focus on customers with high total spending for marketing campaigns and special offers.
#
# Segment-Based Marketing:
# Use clustering to create targeted strategies, offering premium products to high-income segments and budget-friendly options to lower-income segments.
#
# Loyalty Programs:
# Implement programs to reward frequent purchases, encouraging recent buyers to continue spending.
